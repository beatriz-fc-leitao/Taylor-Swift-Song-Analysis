# %% [markdown]
# ### Set Up

# %%
import lyricsgenius
import mysql.connector
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Retrieve Data from API

# %%
genius = lyricsgenius.Genius('-pkLFyIo6ojiKTXbXHgYeNekbeicG2FLuAIURzofhAB1QvVl1Q6X6O0EJAiyaoNK', timeout=None)

# %%
artist = genius.search_artist('Taylor Swift', max_songs=500, sort='popularity')
# Out:
# Searching for songs by Taylor Swift...
#
# Song 1: "All Too Well (10 Minute Version) (Taylor’s Version) [From the Vault]"
# Song 2: "All Too Well (10 Minute Version) (Taylor’s Version) [Live Acoustic]"
# Song 3: "​cardigan"
# Song 4: "​exile"
# Song 5: "Lover"
# Song 6: "​the 1"
# Song 7: "​august"
# Song 8: "Look What You Made Me Do"
# Song 9: "​betty"
# Song 10: "​champagne problems"
# Song 11: "Blank Space"
# Song 12: "End Game"
# Song 13: "​my tears ricochet"
# Song 14: "Anti-Hero"
# Song 15: "You Need To Calm Down"
# Song 16: "ME!"
# Song 17: "​willow"
# Song 18: "...Ready for It?"
# Song 19: "Cruel Summer"
# Song 20: "​invisible string"
# Song 21: "Maroon"
# Song 22: "All Too Well"
# Song 23: "Style"
# Song 24: "​the last great american dynasty"
# Song 25: "​seven"
# Song 26: "​this is me trying"
# Song 27: "​happiness"
# Song 28: "You’re On Your Own, Kid"
# Song 29: "Call It What You Want"
# Song 30: "Delicate"
# Song 31: "​illicit affairs"
# Song 32: "​tolerate it"
# Song 33: "Love Story"
# Song 34: "Question...?"
# Song 35: "Snow On The Beach"
# Song 36: "Bad Blood (Remix)"
# Song 37: "​ivy"
# Song 38: "​mirrorball"
# Song 39: "​evermore"
# Song 40: "Would’ve, Could’ve, Should’ve"
# Song 41: "​peace"
# Song 42: "Gorgeous"
# Song 43: "Karma"
# Song 44: "​gold rush"
# Song 45: "​mad woman"
# Song 46: "Vigilante Shit"
# Song 47: "Don’t Blame Me"
# Song 48: "Midnight Rain"
# Song 49: "Getaway Car"
# Song 50: "The Man"
# Song 51: "​hoax"
# Song 52: "Dress"
# Song 53: "​no body, no crime"
# Song 54: "I Did Something Bad"
# Song 55: "Wildest Dreams"
# Song 56: "The Archer"
# Song 57: "​epiphany"
# Song 58: "Lavender Haze"
# Song 59: "Hits Different"
# Song 60: "Cornelia Street"
# Song 61: "Daylight"
# Song 62: "​’tis the damn season"
# Song 63: "London Boy"
# Song 64: "​the lakes"
# Song 65: "Miss Americana & The Heartbreak Prince"
# Song 66: "Bejeweled"
# Song 67: "Mr. Perfectly Fine (Taylor’s Version) [From the Vault]"
# Song 68: "Death by a Thousand Cuts"
# Song 69: "Bad Blood"
# Song 70: "Sweet Nothing"
# Song 71: "All Of The Girls You Loved Before"
# Song 72: "King of My Heart"
# Song 73: "Shake It Off"
# Song 74: "Bigger Than The Whole Sky"
# Song 75: "Mastermind"
# Song 76: "New Year’s Day"
# Song 77: "​cowboy like me"
# Song 78: "We Are Never Ever Getting Back Together"
# Song 79: "Labyrinth"
# Song 80: "​coney island"
# Song 81: "Afterglow"
# Song 82: "Paper Rings"
# Song 83: "I Forgot That You Existed"
# Song 84: "​dorothea"
# Song 85: "You Belong With Me"
# Song 86: "The Great War"
# Song 87: "False God"
# Song 88: "This Is Why We Can’t Have Nice Things"
# Song 89: "So It Goes..."
# Song 90: "Dancing With Our Hands Tied"
# Song 91: "​l​ong story short"
# Song 92: "I Think He Knows"
# Song 93: "Nothing New (Taylor’s Version) [From the Vault]"
# Song 94: "Clean"
# Song 95: "​marjorie"
# Song 96: "Long Live"
# Song 97: "High Infidelity"
# Song 98: "​r​ight where you left me"
# Song 99: "Soon You’ll Get Better"
# Song 100: "​closure"
# Song 101: "Out Of The Woods"
# Song 102: "Better Man (Taylor’s Version) [From the Vault]"
# Song 103: "Enchanted"
# Song 104: "Dear Reader"
# Song 105: "Paris"
# Song 106: "Why She Disappeared [Poem]"
# Song 107: "22"
# Song 108: "It’s Nice to Have a Friend"
# Song 109: "Holy Ground"
# Song 110: "I Bet You Think About Me (Taylor’s Version) [From the Vault]"
# Song 111: "Wonderland"
# Song 112: "Dear John"
# Song 113: "​it’s time to go"
# Song 114: "Begin Again"
# Song 115: "New Romantics"
# Song 116: "I Knew You Were Trouble"
# Song 117: "This Love"
# Song 118: "State of Grace"
# Song 119: "Glitch"
# Song 120: "You Are in Love"
# Song 121: "You All Over Me (Taylor’s Version) [From the Vault]"
# Song 122: "Everything Has Changed"
# Song 123: "The Story Of Us"
# Song 124: "Carolina"
# Song 125: "Forever Winter (Taylor’s Version) [From the Vault]"
# Song 126: "Safe & Sound"
# Song 127: "Last Kiss"
# Song 128: "Red"
# Song 129: "Lover (Remix)"
# Song 130: "I Know Places"
# Song 131: "Mine"
# Song 132: "Love Story (Taylor’s Version)"
# Song 133: "All You Had to Do Was Stay"
# Song 134: "Treacherous"
# Song 135: "Welcome to New York"
# Song 136: "Better Than Revenge"
# Song 137: "Message In A Bottle (Taylor’s Version) [From the Vault]"
# Song 138: "I Wish You Would"
# Song 139: "If You’re Anything Like Me [Poem]"
# Song 140: "Back to December"
# Song 141: "Run (Taylor’s Version) [From the Vault]"
# Song 142: "Red (Taylor’s Version)"
# Song 143: "Mean"
# Song 144: "Reputation [Prologue]"
# Song 145: "How You Get The Girl"
# Song 146: "Only The Young"
# Song 147: "The Lucky One"
# Song 148: "The Moment I Knew"
# Song 149: "I Knew You Were Trouble (Taylor’s Version)"
# Song 150: "Sparks Fly"
# Song 151: "The Last Time"
# Song 152: "Picture to Burn"
# Song 153: "Innocent"
# Song 154: "Fifteen"
# Song 155: "Sad Beautiful Tragic"
# Song 156: "The Way I Loved You"
# Song 157: "Ours"
# Song 158: "Fearless"
# Song 159: "I Almost Do"
# Song 160: "The Very First Night (Taylor’s Version) [From the Vault]"
# Song 161: "Teardrops On My Guitar"
# Song 162: "Our Song"
# Song 163: "Haunted"
# Song 164: "That’s When (Taylor’s Version) [From the Vault]"
# Song 165: "Don’t You (Taylor’s Version) [From the Vault]"
# Song 166: "Tim McGraw"
# Song 167: "Need"
# Song 168: "Come Back... Be Here"
# Song 169: "White Horse"
# Song 170: "We Were Happy (Taylor’s Version) [From the Vault]"
# Song 171: "Starlight"
# Song 172: "Babe (Taylor’s Version) [From the Vault]"
# Song 173: "Bye Bye Baby (Taylor’s Version) [From the Vault]"
# Song 174: "Never Grow Up"
# Song 175: "Speak Now"
# Song 176: "Beautiful Ghosts"
# Song 177: "Forever & Always"
# Song 178: "Stay Stay Stay"
# Song 179: "Christmas Tree Farm"
# Song 180: "Breathe"
# Song 181: "Ronan"
# Song 182: "Red (Original Demo Recording)"
# Song 183: "I Knew You Were Trouble (Intro)"
# Song 184: "The Best Day"
# Song 185: "If This Was a Movie"
# Song 186: "Hey Stephen"
# Song 187: "Should’ve Said No"
# Song 188: "Let’s Go (Battle)"
# Song 189: "Cold as You"
# Song 190: "Unreleased Songs [Discography List]"
# Song 191: "Girl at Home"
# Song 192: "Untouchable"
# Song 193: "Mary’s Song (Oh My My My)"
# Song 194: "Back to December / Apologize / You’re Not Sorry (Live/2011)"
# Song 195: "You’re Not Sorry"
# Song 196: "State of Grace (Taylor’s Version)"
# Song 197: "Tied Together with a Smile"
# Song 198: "All Too Well (Taylor’s Version)"
# Song 199: "The Way I Loved You (Taylor’s Version)"
# Song 200: "The Other Side Of The Door"
# Song 201: "Fearless (Taylor’s Version)"
# Song 202: "I’m Only Me When I’m With You"
# Song 203: "Change"
# Song 204: "Reputation Magazine Vol. 1"
# Song 205: "September"
# Song 206: "Treacherous (Taylor’s Version)"
# Song 207: "Crazier"
# Song 208: "Superman"
# Song 209: "You Belong With Me (Taylor’s Version)"
# Song 210: "Stay Beautiful"
# Song 211: "The Outside"
# Song 212: "The Moment I Knew (Taylor’s Version)"
# Song 213: "Tell Me Why"
# Song 214: "Picture to Burn (Original Version)"
# "Speak Now [Liner Notes]" is not valid. Skipping.
# "Red [Liner Notes]" is not valid. Skipping.
# Song 215: "Come Back...Be Here (Taylor’s Version)"
# Song 216: "Holy Ground (Taylor’s Version)"
# Song 217: "Jump Then Fall"
# Song 218: "Sad Beautiful Tragic (Taylor’s Version)"
# Song 219: "A Message From Taylor"
# Song 220: "A Place In This World"
# Song 221: "Begin Again (Taylor’s Version)"
# Song 222: "Ronan (Taylor’s Version)"
# Song 223: "The Lucky One (Taylor’s Version)"
# Song 224: "I Almost Do (Taylor’s Version)"
# Song 225: "The Last Time (Taylor’s Version)"
# Song 226: "Invisible"
# Song 227: "Girl At Home (Taylor’s Version)"
# "1989 [Liner Notes]" is not valid. Skipping.
# Song 228: "SuperStar"
# Song 229: "Wildest Dreams (Taylor’s Version)"
# Song 230: "I Know Places (Voice Memo)"
# Song 231: "The Other Side of the Door (Taylor’s Version)"
# Song 232: "Hey Stephen (Taylor’s Version)"
# Song 233: "Come In With the Rain"
# Song 234: "Blank Space (Voice Memo)"
# Song 235: "Untouchable (Taylor’s Version)"
# Song 236: "Fifteen (Taylor’s Version)"
# Song 237: "Eyes Open"
# Song 238: "Everything Has Changed (Taylor’s Version)"
# Song 239: "Sparks Fly (Original Version)"
# Song 240: "22 (Taylor’s Version)"
# Song 241: "Stay Stay Stay (Taylor’s Version)"
# Song 242: "We Are Never Ever Getting Back Together (Taylor’s Version)"
# Song 243: "Anti-Hero (Remix)"
# Song 244: "Breathe (Taylor’s Version)"
# Song 245: "Forever & Always (Taylor’s Version)"
# Song 246: "White Horse (Taylor’s Version)"
# Song 247: "​cardigan (voice memo)"
# Song 248: "A Perfectly Good Heart"
# Song 249: "This Love (Taylor’s Version)"
# Song 250: "Starlight (Taylor’s Version)"
# Song 251: "You’re Not Sorry (Taylor’s Version)"
# Song 252: "Today Was a Fairytale (Taylor’s Version)"
# Song 253: "Macavity"
# Song 254: "Jump Then Fall (Taylor’s Version)"
# Song 255: "Tell Me Why (Taylor’s Version)"
# Song 256: "Drama Queen"
# Song 257: "The Best Day (Taylor’s Version)"
# "1989 [Booklet]" is not valid. Skipping.
# Song 258: "Change (Taylor’s Version)"
# Song 259: "Sweeter Than Fiction"
# Song 260: "Superstar (Taylor’s Version)"
# Song 261: "Come In With The Rain (Taylor’s Version)"
# "Speak Now Tour Setlist" is not valid. Skipping.
# Song 262: "R.E.V.E.N.G.E."
# Song 263: "Sweet Tea and God’s Graces"
# Song 264: "This Is What You Came For (Demo)"
# Song 265: "Dark Blue Tennessee"
# Song 266: "Need You Now"
# Song 267: "Thug Story"
# Song 268: "I Heart ?"
# "Fearless [Liner Notes]" is not valid. Skipping.
# Song 269: "Long Live (Live/2011)"
# Song 270: "State Of Grace (Acoustic Version) (Taylor’s Version)"
# Song 271: "I Wish You Would (Voice Memo)"
# Song 272: "Last Christmas"
# Song 273: "Beautiful Eyes"
# Song 274: "Meet me at midnight"
# Song 275: "A Monster In My Closet!"
# Song 276: "​folklore [Foreword]"
# Song 277: "All Too Well (Sad Girl Autumn Version) - Recorded At Long Pond Studios"
# Song 278: "Album of the Year Acceptance Speech (Grammys 2016)"
# "Reputation Tour Setlist" is not valid. Skipping.
# Song 279: "Permanent Marker"
# Song 280: "Forever & Always (Piano Version) [Taylor’s Version]"
# Song 281: "Didn’t They"
# Song 282: "Clean Speeches"
# Song 283: "Enchanted (Live/2011)"
# Song 284: "Lover [Foreword]"
# Song 285: "Red Tour Costumes"
# Song 286: "Eyes Open (Taylor’s Version)"
# Song 287: "I’d Lie"
# Song 288: "The Trick to Holding On [Poem]"
# Song 289: "Wildest Dreams / Enchanted"
# Song 290: "​the lakes (original version)"
# Song 291: "Forever & Always (Piano Version)"
# "Taylor Swift [Liner Notes]" is not valid. Skipping.
# Song 292: "If This Was a Movie (Taylor’s Version)"
# Song 293: "Me and Britney"
# "1989 Tour Setlist" is not valid. Skipping.
# "Acting Like a Boy*" is not valid. Skipping.
# Song 294: "Long Live/New Year’s Day"
# Song 295: "The Diary of Me"
# Song 296: "Brought Up That Way"
# Song 297: "Angelina"
# Song 298: "Today Was a Fairytale"
# Song 299: "Fearless Tour Costumes"
# Song 300: "This Is Really Happening"
# Song 301: "Never Mind"
# Song 302: "Reputation Tour Costumes"
# Song 303: "Speak Now Tour Costumes"
# Song 304: "What Do You Say"
# "Evermore [Liner Notes]" is not valid. Skipping.
# Song 305: "State of Grace (Acoustic Version)"
# Song 306: "Teardrops on My Guitar (Pop Version)"
# Song 307: "Dear John (Live/2011)"
# Song 308: "Welcome Distraction"
# Song 309: "1989 World Tour Dates"
# Song 310: "Sunshine"
# Song 311: "Stupid Boy"
# Song 312: "Wait for Me"
# Song 313: "​betty (Radio Edit)"
# Song 314: "American Boy"
# Song 315: "Monologue Song (La La La)"
# Song 316: "Better Off"
# Song 317: "Drops of Jupiter (Live/2011)"
# Song 318: "“Bad Blood” Video Breakdown"
# Song 319: "I Need You Now"
# Song 320: "Santa Baby"
# Song 321: "Can’t Stop Loving You (Live Lounge)"
# Song 322: "30 Things I Learned Before Turning 30"
# Song 323: "By The Way"
# Song 324: "Your Anything"
# Song 325: "All Night Diner"
# Song 326: "Christmases When You Were Mine"
# "Red Tour Setlist" is not valid. Skipping.
# Song 327: "A Place In This World (Live from SoHo)"
# Song 328: "I Did Something Bad (Reputation Tour Remix)"
# Song 329: "Better Man (Demo Version)"
# Song 330: "Treacherous (Original Demo Recording)"
# Song 331: "Christmas Must Be Something More"
# Song 332: "Gracie"
# Song 333: "Bad Blood/Should’ve Said No"
# Song 334: "Love Story (Taylor’s Version) [Elvira Remix]"
# Song 335: "The 1989 World Tour - Special Guests"
# Song 336: "Just South of Knowing Why"
# Song 337: "Smokey Black Nights"
# Song 338: "Long Time Going"
# Song 339: "Til Brad Pitt Comes Along"
# Song 340: "You’re On Your Own, Kid (Strings Remix)"
# Song 341: "Am I Ready for Love"
# Song 342: "Baby (live cover)"
# Song 343: "Carolina (Video Version)"
# Song 344: "I Want You Back (Live/2011)"
# Song 345: "Delicate Speeches"
# Song 346: "Tell Me"
# Song 347: "Silent Night"
# Song 348: "Thirteen Blocks (Can’t Call It Love)"
# Song 349: "The Making Of A Song - ‘Gorgeous’"
# Song 350: "Back To December (Acoustic)"
# Song 351: "You Don’t Have to Call  Me"
# Song 352: "Being with My Baby"
# Song 353: "“Songs Taylor Loves” Playlist"
# Song 354: "In the Pouring Rain"
# Song 355: "Taylor Swift’s Reputation (Reputation Tour Intro)"
# Song 356: "White Christmas"
# Song 357: "Better Than Revenge (Live/2011)"
# Song 358: "All Too Well (10 Minute Version) [The Short Film]"
# Song 359: "Matches"
# Song 360: "Love Story (Digital Dog Remix)"
# "Fearless Tour Setlist" is not valid. Skipping.
# "Family" is not valid. Skipping.
# Song 361: "Your Face"
# Song 362: "I Forgot That You Existed (Piano/Vocal)"
# Song 363: "Her"
# Song 364: "Writing Songs About You"
# Song 365: "Closest to a Cowboy"
# Song 366: "Perfect Have I Loved"
# Song 367: "Ten Dollars and a Six Pack"
# Song 368: "Lucky You"
# Song 369: "​cardigan (cabin in candlelight version)"
# Song 370: "Who I’ve Always Been"
# Song 371: "Firefly"
# Song 372: "Don’t Hate Me for Loving You"
# Song 373: "What To Wear"
# Song 374: "Thinkin’ ’Bout You"
# Song 375: "You Do"
# Song 376: "My Cure"
# Song 377: "Clean/Long Live/New Year’s Day"
# Song 378: "Live for the Little Things"
# Song 379: "Lover (First Dance Remix)"
# Song 380: "Sweet Nothing (Piano Remix)"
# Song 381: "...Ready for It? (BloodPop® Remix)"
# Song 382: "Teardrops On My Guitar (Alternate Demo)"
# Song 383: "Making Up for Lost Love"
# Song 384: "Ain’t Nothing ’Bout You"
# Song 385: "Style / Love Story / You Belong With Me"
# Song 386: "Breathless"
# Song 387: "My Turn to Be Me"
# Song 388: "American Girl"
# Song 389: "The Future of Music Is a Love Story"
# Song 390: "Sugar"
# Song 391: "Point of View"
# Song 392: "Animal"
# Song 393: "​willow (dancing witch version) [Elvira Remix]"
# "Castles Crumbling*" is not valid. Skipping.
# Song 394: "Honey Baby"
# Song 395: "Riptide"
# Song 396: "​willow (lonely witch version)"
# Song 397: "I Wished on a Plane"
# Song 398: "Lover (Piano/Vocal)"
# "The Eras Tour Setlist" is not valid. Skipping.
# Song 399: "​cardigan / august / willow (Grammys 2021)"
# Song 400: "​exile (the long pond studio sessions)"
# Song 401: "Love to Lose"
# Song 402: "​willow (90's trend remix)"
# Song 403: "Our Last Night"
# Song 404: "We Are Never Ever Getting Back Together/This Is Why We Can’t Have Nice Things"
# Song 405: "I Know What I Want"
# Song 406: "For You (4 U)"
# Song 407: "I Used to Fly"
# Song 408: "​my tears ricochet (the long pond studio sessions)"
# Song 409: "Taylor Swift’s First Phone Call With Tim McGraw"
# Song 410: "Brand New World"
# Song 411: "​august (the long pond studio sessions)"
# Song 412: "Fall Back on You"
# Song 413: "Cross My Heart"
# Song 414: "All You Had To Do Was Stay Speeches"
# Song 415: "Nashville (Live/2011)"
# Song 416: "That’s Life"
# Song 417: "Fearless/I’m Yours/Hey, Soul Sister (Live/2011)"
# Song 418: "Check Out This View"
# Song 419: "Under My Head"
# Song 420: "Speak Now (Live/2011)"
# Song 421: "Sugar, We’re Going Down"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Duomo-wildest-dreams-lyrics
# Song 422: "Same Girl"
# Song 423: "Mandolin"
# Song 424: "Should’ve Said No (Alternate Version)"
# Song 425: "Spinning Around"
# Song 426: "One Way Ticket"
# Song 427: "Haunted (Live/2011)"
# Song 428: "Just A Dream"
# Song 429: "Picture to Burn (Live From SoHo)"
# Song 430: "​cardigan (the long pond studio sessions)"
# Song 431: "Rain Song"
# Song 432: "Tim McGraw (Demo)"
# "1989 Interview with Paul McGuire" is not valid. Skipping.
# Song 433: "Cornelia Street (Live from Paris)"
# Song 434: "Taylor Swift Tour Guide"
# Song 435: "Never Fade"
# Song 436: "Bette Davis Eyes (Live/2011)"
# Song 437: "Made Up You"
# Song 438: "End Game (Solo Version)"
# Song 439: "How To Save A Life"
# Song 440: "Down Came the Rain"
# Song 441: "Love They Haven’t Thought of Yet"
# "Bother Me*" is not valid. Skipping.
# Song 442: "Tennessee"
# "Anymore*" is not valid. Skipping.
# Song 443: "Baby"
# Song 444: "I’m Looking Out for You"
# Song 445: "The Middle"
# Song 446: "Taylor Swift’s Chart History"
# Song 447: "This Here Guitar"
# Song 448: "The Sweet Escape (Live/2011)"
# "Goodbye Butterfly*" is not valid. Skipping.
# Song 449: "Look At You Like That*"
# Song 450: "​willow (moonlit witch version)"
# Song 451: "Last Kiss (Live/2011)"
# "City of Lover: Setlist" is not valid. Skipping.
# "Scream" is not valid. Skipping.
# Song 452: "Hopelessly Devoted To You"
# Song 453: "I’m Every Woman"
# Song 454: "Daylight (Live from Paris)"
# Song 455: "Lose Yourself / Smile"
# Song 456: "Can I Go with You"
# Song 457: "​the 1 (the long pond studio sessions)"
# Song 458: "Kid in the Crowd"
# Song 459: "Reputation Tour Book Intro"
# Song 460: "​betty (Live from the 2020 Academy of Country Music Awards)"
# Song 461: "Long Live Speeches"
# Song 462: "You Need To Calm Down (Clean Bandit Remix)"
# Song 463: "The Man (Live From Paris)"
# Song 464: "Billboard Woman of the Decade Speech"
# Song 465: "Stay Stay Stay / Ho Hey"
# "Boys and Love*" is not valid. Skipping.
# Song 466: "You’re Not Sorry / What Goes Around.../...Comes Around"
# "His Lies" is not valid. Skipping.
# Song 467: "Umbrella (Live from SoHo)"
# "Formula 1 2016 Setlist" is not valid. Skipping.
# Song 468: "​this is me trying (the long pond studio sessions)"
# Song 469: "Long Live (Remix)"
# Song 470: "All Of The Girls (Demo)"
# Song 471: "Death by a Thousand Cuts (Live from Paris)"
# Song 472: "Message In A Bottle (Taylor’s Version) (Fat Max G Remix)"
# Song 473: "Reputation Tour Special Guests"
# Song 474: "​the lakes (the long pond studio sessions)"
# Song 475: "Barnyard Song"
# Song 476: "Drive (For Daddy Gene)"
# Song 477: "ME! (feat. Brendon Urie of Panic! At The Disco) (Live From The Billboard Music Awards)"
# "Beautiful Day*" is not valid. Skipping.
# Song 478: "Irreplaceable"
# Song 479: "​willow (original songwriting demo)"
# Song 480: "Christmas Tree Farm (Old Timey Version)"
# Song 481: "The Last Time (VEVO Version)"
# Song 482: "Taylor Swift Responds To Kanye’s ‘Famous’ Lyric"
# Song 483: "The Making Of A Song - ‘King of My Heart’"
# "Too Beautiful" is not valid. Skipping.
# Song 484: "AMAs Artist of the Decade Performance"
# Song 485: "Playlist by ME!"
# Song 486: "Nashville"
# Song 487: "​seven (the long pond studio sessions)"
# Song 488: "Dancing In The Dark / Livin’ On A Prayer"
# Song 489: "2022 New York University Commencement Speech"
# Song 490: "​mirrorball (the long pond studio sessions)"
# Song 491: "​betty (the long pond studio sessions)"
# "I Can See You*" is not valid. Skipping.
# "Foolish One" is not valid. Skipping.
# Song 492: "The Story Of Us (Live/2011)"
# Song 493: "Anti-Hero (Acoustic Version)"
# Song 494: "That’s What You Get"
# Song 495: "​the last great american dynasty (the long pond studio sessions)"
# "None of the Above" is not valid. Skipping.
# Song 496: "Anti-Hero (ILLENIUM Remix)"
# Song 497: "​illicit affairs (the long pond studio sessions)"
# Song 498: "​hoax (the long pond studio sessions)"
# "Wonderful Things*" is not valid. Skipping.
# Song 499: "Who Knew / Unpretty"
# Song 500: "Here You Come Again"
#
# Reached user-specified song limit (500).
# Done. Found 500 songs.

# %% [markdown]
# ### Reformat Data

# %%
titles = []
lyrics = []

for song in artist.songs:
    titles.append(song.title)
    lyrics.append(song.lyrics)

# %%
# create dictionary and then dataframe with data
data = {'title': titles, 'lyrics': lyrics}

df = pd.DataFrame(data)
df.to_csv('genius_data_unprocessed.csv')

# %% [markdown]
# ### Clean Data

# %% [markdown]
# First, I cleaned the data from the 'lyrics' column using the following steps:
# 1. Separate the lyrics from the additional information in the column
# 2. Create new columns from original column:
#     - contributors: number of song contributors
#     - translations: languages into which song is translated to
#     - translation_count: number of languages into which song is translated to
#     - verse: number of verses in song
#     - refrain: number of refrains
#     - pre-chorus: number of pre-choruses
#     - chorus: number of choruses
#     - post-chorus: number of post choruses
#     - bridge: number of bridges
#     - outro: number of outros
# 3. Remove section names from the lyrics column to obtain just the text
# 4. Convert all lyrics to lowercase

# %% [markdown]
# Step 1

# %%
#create new column with additional info
df['additional_info'] = df['lyrics'].apply(lambda x: x.split('Lyrics')[0].strip())

# %%
#alter lyrics column to keep only lyrics and remove additional information
df['lyrics'] = df['lyrics'].apply(lambda x: x.split('Lyrics')[1].strip())

# %% [markdown]
# Step 2

# %%
#create column with number of contributors per song
df['contributors'] = df['additional_info'].apply(lambda x: x.split('Contributors')[0].strip())

# %%
# Define a lambda function to extract the translations from the 'additional_info' column
def extract_translations(x, title):
    start_index = x.find('Translations')
    if start_index == -1:
        return np.NaN
    end_index = x.find(title)
    return x[start_index + 12:end_index].strip()

# Apply the lambda function to each row of the 'additional_info' column
df['translations'] = df.apply(lambda x: extract_translations(x['additional_info'], x['title']), axis=1)

# %%
#create new column with the number of translations for each song
def translation_count(row):
    if isinstance(row, str):
        pattern = r'[A-Z]'
        return len(re.findall(pattern, row))
    else:
        return 0

# apply the function to the 'lyrics' column and create a new column 'capital_count'
df['translation_count'] = df['translations'].apply(translation_count)

# %%
#drop additional_info as all info has been registered in other columns
df.drop(columns='additional_info', inplace=True)

# %%
#define typical song sections - found on https://blog.songtrust.com/the-parts-of-a-song
section_list = ['verse', 'refrain', 'pre-chorus', 'chorus', 'post-chorus', 'bridge', 'outro']

# create new columns for count of each section in each song
for section in section_list:
    pattern = r'\[{}.*\]'.format(section)
    df[section] = df['lyrics'].str.count(pattern, flags=re.IGNORECASE)

# %% [markdown]
# Step 3

# %%
# define regex pattern
pattern_1 = r"\[.*?\]"

# remove section names from lyrics column
df['lyrics'] = df['lyrics'].apply(lambda x: re.sub(pattern_1, "", x))

# %% [markdown]
# Step 4

# %%
#convert lyrics to lower case
df['lyrics'] = df['lyrics'].str.lower()

# %% [markdown]
# Then I cleaned the data in the 'title' column using the following steps:
# 1. Remove content in parentheses and brackets
# 2. Convert all titles to lowercase

# %%
# define function to remove parenthese and brackets ffrom any column in df
def pre_process(df, column_name):
    # define regex patterns
    pattern_1 = r"\[.*?\]"
    pattern_2 = r"\(.*?\)"
    
    # remove content in parentheses and brackets from each element in the specified column
    df[column_name] = df[column_name].apply(lambda x: re.sub(pattern_1, "", x))
    df[column_name] = df[column_name].apply(lambda x: re.sub(pattern_2, "", x))
    
    # convert text to lowercase
    df[column_name] = df[column_name].str.lower().str.strip()
    
    # remove zero width character from  column
    df[column_name] = df[column_name].apply(lambda x: x.replace('\u200b', ''))
    
    return df

# %%
# remove parentheses and brackets from title column of df
df = pre_process(df, 'title')

# %%
# drop duplicate titles
df = df.drop_duplicates(subset='title')

# %% [markdown]
# ### Link Songs with Respective Albums

# %% [markdown]
# The Genius API makes it difficult to obtain the album that each track belongs to, so to connect the songs to their respective album, I used a dataset found on Kaggle (https://www.kaggle.com/datasets/jarredpriester/taylor-swift-spotify-dataset?select=taylor_swift_spotify.csv) 'taylor_swift_spotify.csv' which contains informaiton about Taylor Swift songs and their respective albums (originally obtained from the spotify API). I joined the relevant columns of the kaggle dataset with the dataframe I previously created. This join results in the following new columns:
#
#
# - album: the album to which the song belongs
# - track_number: number of song in album
# - release date: release date of album
# - length: song length in milliseconds
# - popularity: percent popularity of the song based on Spotify's algorithm
# - danceability: how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity
# - accousticness: how acoustic a song is
# - energy: measure of intensity and activity
# - instrumentalness: amount of vocals in the song
# - liveness: probability that the song was recorded with a live audience
# - loudness: tendency of music to be recorded at steadily higher volumes
# - speechiness: presence of spoken words in a track
# - valence: measure of how happy or sad the song sounds
# - tempo: beats per minute

# %%
# Load the Taylor Swift Kaggle dataset 
ts_df = pd.read_csv("taylor_swift_spotify.csv")

# %%
# preview dataset
ts_df.head(2)
# Out:
#             name      album release_date  track_number  acousticness  \
# 0  lavender haze  midnights   2022-10-22             1        0.2040
# 1         maroon  midnights   2022-10-22             2        0.0593
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.735   0.444            0.0012    0.1700   -10.519       0.0684
# 1         0.658   0.378            0.0000    0.0976    -8.300       0.0379
#
#      tempo  valence  popularity  duration_ms
# 0   97.038   0.0984          76       202395
# 1  108.034   0.0382          75       218270

# %%
# drop unecessary columns
ts_df.drop(columns=['Unnamed: 0', 'uri', 'id'], inplace=True)

# %%
# pre-proccess name and album columns
ts_df = pre_process(ts_df, 'name')
ts_df = pre_process(ts_df, 'album')

# %%
#join dataframes
merged_df = df.merge(ts_df, left_on='title', right_on='name', how='left')

#remove ducplicated name column
merged_df.drop(columns='name', inplace=True)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              31 non-null     object
#  1   lyrics             31 non-null     object
#  2   contributors       31 non-null     object
#  3   translations       22 non-null     object
#  4   translation_count  31 non-null     int64
#  5   verse              31 non-null     int64
#  6   refrain            31 non-null     int64
#  7   pre-chorus         31 non-null     int64
#  8   chorus             31 non-null     int64
#  9   post-chorus        31 non-null     int64
#  10  bridge             31 non-null     int64
#  11  outro              31 non-null     int64
#  12  album              31 non-null     object
#  13  release_date       31 non-null     object
#  14  track_number       31 non-null     int64
#  15  acousticness       31 non-null     float64
#  16  danceability       31 non-null     float64
#  17  energy             31 non-null     float64
#  18  instrumentalness   31 non-null     float64
#  19  liveness           31 non-null     float64
#  20  loudness           31 non-null     float64
#  21  speechiness        31 non-null     float64
#  22  tempo              31 non-null     float64
#  23  valence            31 non-null     float64
#  24  popularity         31 non-null     int64
#  25  duration_ms        31 non-null     int64
# dtypes: float64(9), int64(11), object(6)
# memory usage: 6.5+ KB

# %%
merged_df.isna().sum()
# Out:
# title                0
# lyrics               0
# contributors         0
# translations         9
# translation_count    0
# verse                0
# refrain              0
# pre-chorus           0
# chorus               0
# post-chorus          0
# bridge               0
# outro                0
# album                0
# release_date         0
# track_number         0
# acousticness         0
# danceability         0
# energy               0
# instrumentalness     0
# liveness             0
# loudness             0
# speechiness          0
# tempo                0
# valence              0
# popularity           0
# duration_ms          0
# dtype: int64

# %% [markdown]
# turn release date into date time
